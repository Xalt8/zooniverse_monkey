# %%
from Code import functions as funcs
import matplotlib.pyplot as plt
import cv2
import numpy as np
import pandas as pd
from pathlib import Path

# %%
total_df = funcs.get_image_df()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\singh\OneDrive\MSc_in_AI\Python\Zooinverse\image_annotations.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/singh/OneDrive/MSc_in_AI/Python/Zooinverse/image_annotations.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> total_df = funcs.get_image_df()
#
# File c:\Users\singh\OneDrive\MSc_in_AI\Python\Zooinverse\Code\functions.py:68, in get_image_df()
#      65 def get_image_df() -> pd.DataFrame:
#      66     """Returns a dataframe with all the image data """
# ---> 68     set4_df = pd.read_excel(r"../AI Training Sets-20231024T092556Z-001\AI Training Sets\Set4-1_TrainingData_20210526.xlsx", index_col=None)
#      69     set4_df = set4_df[set4_df.columns[:-2]]
#      70     set4_df["Animal Date"] = pd.to_datetime(set4_df["Animal Date"])
#
# ...

# %%
total_df = functions.train_test_split_df(total_df=total_df)

# %%
image_annotations = (functions.get_image_annotation(image_name=image_file_name, total_df=total_df) 
                     for image_file_name in total_df['Image File'].values)

# %%
im_an = next(image_annotations)
print(im_an.image_name)
im_an.display_annotations()
# Out:
# A014_18Z_T15092_MID_x40_z0_i01j29.jpg

# %%
functions.make_yolo_directory()

# %%
total_df.head()
# Out:
#   Animal ID Animal Date  Image ID                             Image File  \
# 0       18Z  2015-11-18  55725659  A014_18Z_T15092_MID_x40_z0_i01j06.jpg
# 1       18Z  2015-11-18  55726671  A014_18Z_T15092_MID_x40_z0_i01j29.jpg
# 2       18Z  2015-11-18  55727023  A014_18Z_T15092_MID_x40_z0_i01j37.jpg
# 3       18Z  2015-11-18  55727111  A014_18Z_T15092_MID_x40_z0_i01j39.jpg
# 4       18Z  2015-11-18  55727199  A014_18Z_T15092_MID_x40_z0_i01j41.jpg
#
#    x_coord  y_coord wbc_class   set train_test_val
# 0      183      183         N  Set4          Train
# 1      553      881         L  Set4          Train
# 2      132      848         M  Set4           Test
# 3      278      372         E  Set4          Train
# 4      821      391         N  Set4            Val

# %%
im_an
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\singh\OneDrive\MSc_in_AI\Python\Zooinverse\image_annotations.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/singh/OneDrive/MSc_in_AI/Python/Zooinverse/image_annotations.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> im_an
#
# NameError: name 'im_an' is not defined
